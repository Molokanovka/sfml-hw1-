# %%
import pandas as pd

# %%
# (1) Используя параметры pandas прочитать красиво пандас (подвох что заголовки - первые 2 линии)
df = pd.read_csv(
    'default_of_credit_card_clients.csv',
        sep=';',
        header=1    
) #TODO

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...                      0          0          0         0
# 1             ...                   3272       3455       3261         0
# 2             ...                  14331      14948      15549      1518
# 3             ...                  28314      28959      29547      2000
# 4             ...                  20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
# (2) выведите, что за типы переменных, сколько пропусков,
# для численных значений посчитайте пару статистик (в свободной форме)

# %%
#TODO
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df.describe(percentiles=[0.99])
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 99%    29700.010000   500000.000000      2.000000      5.000000      3.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# std        9.217904      1.123802      1.197186      1.196868      1.169139
# ...

# %%
# (3) посчитать число женщин с университетским образованием
# SEX (1 = male; 2 = female). 
# EDUCATION (1 = graduate school; 2 = university; 3 = high school; 4 = others). 
#TODO

# %%
female_with_high_education = df[
    df['EDUCATION'].isin([2.0]) & df['SEX'].isin([2.0])
]

# %%
female_with_high_education.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8656 entries, 0 to 29180
# Data columns (total 25 columns):
# ID                            8656 non-null int64
# LIMIT_BAL                     8656 non-null int64
# SEX                           8656 non-null int64
# EDUCATION                     8656 non-null int64
# MARRIAGE                      8656 non-null int64
# AGE                           8656 non-null int64
# PAY_0                         8656 non-null int64
# PAY_2                         8656 non-null int64
# PAY_3                         8656 non-null int64
# PAY_4                         8656 non-null int64
# PAY_5                         8656 non-null int64
# PAY_6                         8656 non-null int64
# BILL_AMT1                     8656 non-null int64
# BILL_AMT2                     8656 non-null int64
# BILL_AMT3                     8656 non-null int64
# BILL_AMT4                     8656 non-null int64
# BILL_AMT5                     8656 non-null int64
# ...

# %%
# (4) Сгрупировать по "default payment next month" и посчитать медиану для всех показателей начинающихся на BILL_ и PAY_
#TODO

# %%
tmp = df.loc[1:30000 ,'BILL_AMT4':'default payment next month']

# %%
tmp.groupby('default payment next month').median()
# Out:
#                             BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# default payment next month
# 0                             19000.0    17998.0    16679.0    2459.5
# 1                             19121.0    18487.0    18034.0    1639.0
#
#                             PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# default payment next month
# 0                             2247.5    2000.0    1734.0    1765.0    1706.0
# 1                             1534.0    1224.0    1000.0    1000.0    1000.0

# %%
# (5) постройте сводную таблицу (pivot table) по SEX, EDUCATION, MARRIAGE

df.pivot_table #TODO
# Out:
# <bound method pivot_table of           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# 5          6      50000    1          1         2   37      0      0      0
# 6          7     500000    1          1         2   29      0      0      0
# 7          8     100000    2          2         2   23      0     -1     -1
# 8          9     140000    2          3         1   28      0      0      2
# 9         10      20000    1          3         2   35     -2     -2     -2
# 10        11     200000    2          3         2   34      0      0      2
# ...

# %%
df.pivot_table('MARRIAGE', 'SEX','EDUCATION', 'count')
# Out:
# EDUCATION  0     1     2     3   4    5   6
# SEX
# 1          8  4354  5374  1990  42   95  25
# 2          6  6231  8656  2927  81  185  26

# %%
# (6) Создать новый строковый столбец в data frame-е, который:
# принимает значение A, если значение LIMIT_BAL <=10000
# принимает значение B, если значение LIMIT_BAL <=100000 и >10000
# принимает значение C, если значение LIMIT_BAL <=200000 и >100000
# принимает значение D, если значение LIMIT_BAL <=400000 и >200000
# принимает значение E, если значение LIMIT_BAL <=700000 и >400000
# принимает значение F, если значение LIMIT_BAL >700000

#TODO

# %%
d = df

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
localData =  d['LIMIT_BAL']

# %%
def zip(x):
    if (x <= 10000) :
        return 'A' 
    elif (x <= 100000) & (x > 10000) :
        return 'B' 
    elif (x <= 200000) & (x > 100000) :
        return 'C' 
    elif (x <= 400000) & (x > 200000) :
        return 'D' 
    elif (x <= 700000) & (x > 400000) :
        return 'E' 
    else : 
         return 'F'

# %%
d['NewData']=localData.map(zip)

# %%
d['NewData'].head(10)
# Out:
# 0    B
# 1    C
# 2    B
# 3    B
# 4    B
# 5    B
# 6    E
# 7    B
# 8    C
# 9    B
# Name: NewData, dtype: object

# %%
# %matplotlib inline

# %%
# (7) постироить распределение LIMIT_BAL (гистрограмму)

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %%
x = d['LIMIT_BAL']

# %%
num_bins = 30
n, bins, patches = plt.hist(x, num_bins, facecolor='blue', alpha=0.6)
plt.show()

# %%
# (8) построить зависимость кредитного лимита от образования для каждого пола
# график необходимо сделать очень широким (на весь экран)
df.head() #TODO
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#     ...     BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# 0   ...             0          0         0       689         0         0
# 1   ...          3455       3261         0      1000      1000      1000
# 2   ...         14948      15549      1518      1500      1000      1000
# 3   ...         28959      29547      2000      2019      1200      1100
# 4   ...         19146      19131      2000     36681     10000      9000
#
#    PAY_AMT5  PAY_AMT6  default payment next month  NewData
# ...

# %%
fig, ax = plt.subplots(figsize=(10,5))
d.pivot_table('LIMIT_BAL', 'EDUCATION', 'SEX', 'count').plot(kind='bar', stacked=True, ax=ax)

# %%
# (9) построить зависимость кредитного лимита и образования только для одного из полов

#TODO

# %%
x = d[d['SEX']==1]
y = d[d['SEX']==2]

# %%
fig, ax = plt.subplots(figsize=(10,5))
x.pivot_table('LIMIT_BAL', 'EDUCATION', 'SEX', 'count').plot(kind='bar', facecolor='green', stacked=True, ax=ax)

# %%
fig, ax = plt.subplots(figsize=(10,5))
y.pivot_table('LIMIT_BAL', 'EDUCATION', 'SEX', 'count').plot(kind='bar', stacked=True, ax=ax)

# %%
# (10) построить большой график (подсказка - используя seaborn) для построения завимисости всех возможных пар параметров
# разным цветом выделить разные значение "default payment next month"
# (но так как столбцов много - картинка может получиться "монструозной")
# (поэкспериментируйте над тем как построить подобное сравнение параметров)
# (подсказка - ответ может состоять из несколькольких графиков)
# (если не выйдет - программа минимум - построить один график со всеми параметрами)
import seaborn as sns

#TODO

# %%
sns.pairplot(df, hue='LIMIT_BAL')
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
